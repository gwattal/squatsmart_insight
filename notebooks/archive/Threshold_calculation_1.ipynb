# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("stance_width_data.csv")
df2=pd.read_csv("stance_width_data2.csv")

# %%
cf=df2.confidence

# %%
df['confidence_min']=cf

# %%
df
# Out:
#     Unnamed: 0         name    stance                           label-1  \
# 0            6     images17  0.000000                 Not enough  info
# 1           27     images28  0.095583                            Narrow
# 2            4      index31  0.658245                            Narrow
# 3           19     index_11  0.853401                            Narrow
# 4           14     images24  0.894968                            Narrow
# 5           26     images16  0.954208                            Narrow
# 6           22     images25  0.988986                ok/slightly narrow
# 7           12     images20  0.999950                ok/slightly narrow
# 8           28     images15  1.027805                ok/slightly narrow
# 9            0  image22.png  1.088060                           ok/good
# 10           7  image23.png  1.091162                          ok/good
# 11          24      index33  1.096472                           ok/good
# ...

# %%
df=df.rename(columns={"confidence": "confidence_mean"})

# %%
df
# Out:
#     Unnamed: 0         name    stance                           label-1  \
# 0            6     images17  0.000000                 Not enough  info
# 1           27     images28  0.095583                            Narrow
# 2            4      index31  0.658245                            Narrow
# 3           19     index_11  0.853401                            Narrow
# 4           14     images24  0.894968                            Narrow
# 5           26     images16  0.954208                            Narrow
# 6           22     images25  0.988986                ok/slightly narrow
# 7           12     images20  0.999950                ok/slightly narrow
# 8           28     images15  1.027805                ok/slightly narrow
# 9            0  image22.png  1.088060                           ok/good
# 10           7  image23.png  1.091162                          ok/good
# 11          24      index33  1.096472                           ok/good
# ...

# %%
df.to_csv("stance_width_data.csv")
