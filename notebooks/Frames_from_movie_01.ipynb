# %%
import cv2
print(cv2.__version__)
vidcap = cv2.VideoCapture('/Users/gwattal/squatsmart/videos/MOV_0001.mp4')
success=True
count = 1
while success:
    success,image = vidcap.read()
    plt.imshow(image)
    cv2.imwrite("Users/gwattal/squatsmart/frames/MOV_0001_frame%d.jpg" % count, image)  # save frame as JPEG file
    success,image = vidcap.read()
    print ('Read a new frame: ', success)
    count += 1
# Out:
# 4.2.0
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# ...

# %%
# Program To Read video 
# and Extract Frames 
import cv2 

# Function to extract frames 
def FrameCapture(pathvideo): 

    # Path to video file 
    vidObj = cv2.VideoCapture(pathvideo) 

    # Used as counter variable 
    count = 1

    # checks whether frames were extracted 
    success = True

    while success: 
        # vidObj object calls read 
        # function extract frames 
        success, image = vidObj.read() 
        # Saves the frames with frame-count 
        plt.imshow(image)
        #cv2.imwrite("/Users/gwattal/squatsmart/frames/MOV_0001_frame%d.jpg" %count, image) 
        count += 1


# Calling the function
pathvideo="~/squatsmart/videos/MOV_0001.mp4"
pathframe="~/squatsmart/frames/"
FrameCapture(pathvideo)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-5abe08860ea7> in <module>
#      28 pathvideo="~/squatsmart/videos/MOV_0001.mp4"
#      29 pathframe="~/squatsmart/frames/"
# ---> 30 FrameCapture(pathvideo)
#
# <ipython-input-24-5abe08860ea7> in FrameCapture(pathvideo)
#      20         success, image = vidObj.read()
#      21         # Saves the frames with frame-count
# ---> 22         plt.imshow(image)
#      23         #cv2.imwrite("/Users/gwattal/squatsmart/frames/MOV_0001_frame%d.jpg" %count, image)
#      24         count += 1
#
# ~/Library/Python/3.7/lib/python/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2649         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
# ...

# %%
vidObj = cv2.VideoCapture("/Users/gwattal/squatsmart/videos/MOV_0001.mp4")

# %%
success, image = vidObj.read()

# %%
import matplotlib.pyplot as plt
plt.imshow(image)

# %%
count=3
cv2.imwrite("/Users/gwattal/squatsmart/frames/MOV_0001_frame%d.jpg"%count, image)
# Out:
# True

# %%
success
# Out:
# True

# %%
image
# Out:
# array([[[120, 128, 140],
#         [118, 126, 138],
#         [118, 126, 137],
#         ...,
#         [ 13,  29,  59],
#         [ 11,  28,  56],
#         [ 24,  41,  69]],
#
#        [[113, 121, 133],
#         [110, 118, 130],
#         [110, 118, 129],
#         ...,
#         [ 10,  26,  56],
#         [ 16,  33,  61],
#         [ 21,  38,  66]],
#
#        [[118, 127, 136],
#         [116, 125, 134],
#         [117, 127, 133],
#         ...,
#         [ 21,  36,  68],
#         [ 15,  31,  61],
#         [ 15,  31,  61]],
#
#        ...,
#
#        [[248, 254, 255],
#         [248, 254, 255],
#         [248, 254, 255],
#         ...,
#         [ 31,  65, 106],
#         [ 32,  66, 107],
#         [ 26,  60, 101]],
#
#        [[248, 254, 255],
#         [248, 254, 255],
#         [248, 254, 255],
#         ...,
#         [ 33,  62, 104],
#         [ 33,  61, 103],
#         [ 33,  61, 103]],
#
#        [[248, 254, 255],
#         [248, 254, 255],
#         [248, 254, 255],
# ...
